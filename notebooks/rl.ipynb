# %%
# Clone repository
import os, sys 
os.chdir("/content")
if not os.path.isdir("RL_DEMO"):
  # !git clone https://github.com/Kyu3224/RL_DEMO.git
else:
  print("Cloned Directory already exists")

os.chdir("/content/RL_DEMO")
print("Current Directory: ", os.getcwd())

sys.path.insert(0, "/content/RL_DEMO")
# Out:
# Cloned Traj already exists!
# /home/kyu/Desktop/workspace/RL_DEMO/RL_DEMO
# Current directory:  /home/kyu/Desktop/workspace/RL_DEMO/RL_DEMO

# %%
# Install dependencies
import importlib
from src import env
importlib.reload(env)
env.print_hi()
# Out:
# hs
